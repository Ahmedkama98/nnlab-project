# %%
import tensorflow as tf 
import numpy as np 
N,D,H =64,100,100
x=tf.placeholder(tf.float32,shape=(N,D))
y=tf.placeholder(tf.float32,shape=(N,D))
w1=tf.Variable(tf.random_normal((D,H)))
w2=tf.Variable(tf.random_normal((H,D)))

h=tf.maximum(tf.matmul(x,w1),0)
y_pred=tf.matmul(h,w2)
diff=y_pred-y
loss=tf.reduce_mean(tf.reduce_sum(diff**2,axis=1))
grad_w1, grad_w2=tf.gradients(loss, [w1,w2])

learning_rate=1e-5
new_w1=w1.assign(w1-learning_rate*grad_w1)
new_w2=w1.assign(w2-learning_rate*grad_w2)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    values={x:np.random.randn(N,D),
            y:np.random.randn(N,D)}
    for t in range(50):
        loss_val=sess.run([loss],feed_dict=values)
        print(loss_val)
# Out:
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]
# [506299.2]

# %%
import tensorflow as tf 
import numpy as np 


n,d,h=64,1000,100
x = tf.placeholder(tf.float32, shape=(n,d))
y = tf.placeholder(tf.float32, shape=(n,d))
w1 = tf.Variable(tf.random_normal((d,h)))
w2 = tf.Variable(tf.random_normal((h,d)))

h = tf.maximum(tf.matmul(x,w1),0)
y_pred = tf.matmul(h,w2)
diff = y_pred -y
loss = tf.reduce_mean(tf.reduce_sum(diff ** 2,axis=1))

grad_w1,grad_w2 =tf.gradients(loss,[w1,w2])

learning_rate=1e-5
new_w1 = w1.assign(w1 - learning_rate * grad_w1)
new_w2 = w2.assign(w2 - learning_rate * grad_w2)
update = tf.group(new_w1,new_w2)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    valuse = {x: np.random.randn(n,d),
             y : np.random.randn(n,d),}
    losses = []
    for t in range(50):
        loss_val,_= sess.run([loss,update] , feed_dict=valuse)
        print(loss_val)
# Out:
# 49223056.0
# 17868170.0
# 9408106.0
# 5527972.0
# 3482388.5
# 2282595.0
# 1545294.2
# 1074274.8
# 760716.6
# 546953.25
# 398341.8
# 293275.75
# 217959.05
# 163293.22
# 123176.47
# 93470.984
# 71303.164
# 54686.543
# 42190.156
# 32721.328
# 25513.504
# 19997.305
# 15762.66
# 12499.15
# 9975.975
# 8019.04
# 6497.323
# 5311.098
# 4384.2354
# 3658.8591
# 3090.0999
# 2643.3452
# 2291.8882
# 2015.0933
# 1796.7104
# 1624.1848
# 1487.7571
# 1379.7869
# 1294.2981
# 1226.5564
# 1172.844
# 1130.2894
# 1096.5505
# 1069.7659
# 1048.5015
# 1031.646
# 1018.3074
# 1007.77344
# 999.4563
# 992.93146

# %% [markdown]
# ## use an optimizer to
# . compute gradients and
# . update weights

# %%
import tensorflow as tf 
import numpy as np 


n,d,h=64,1000,100
x = tf.placeholder(tf.float32, shape=(n,d))
y = tf.placeholder(tf.float32, shape=(n,d))
w1 = tf.Variable(tf.random_normal((d,h)))
w2 = tf.Variable(tf.random_normal((h,d)))

h = tf.maximum(tf.matmul(x,w1),0)
y_pred = tf.matmul(h,w2)
diff = y_pred -y
loss = tf.reduce_mean(tf.reduce_sum(diff ** 2,axis=1))


optimizer = tf.train.GradientDescentOptimizer(1e-5)
updates = optimizer.minimize(loss)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    valuse = {x: np.random.randn(n,d),
             y : np.random.randn(n,d),}
    losses = []
    for t in range(50):
        loss_val,_= sess.run([loss,updates] , feed_dict=valuse)
        print(loss_val)
# Out:
# 50712028.0
# 17540138.0
# 9158170.0
# 5364865.5
# 3366396.8
# 2213713.0
# 1506389.4
# 1051634.5
# 749022.3
# 542082.9
# 397515.72
# 294707.34
# 220463.1
# 166051.94
# 126000.375
# 96209.21
# 73867.16
# 57005.434
# 44211.14
# 34450.008
# 26967.549
# 21194.99
# 16747.59
# 13306.465
# 10634.726
# 8555.848
# 6933.815
# 5665.129
# 4670.8413
# 3890.145
# 3276.1606
# 2792.5735
# 2411.102
# 2109.6968
# 1871.6189
# 1683.3513
# 1534.3354
# 1416.2936
# 1322.7552
# 1248.5498
# 1189.7344
# 1143.0497
# 1106.0049
# 1076.6013
# 1053.2794
# 1034.7764
# 1020.10614
# 1008.5049
# 999.32135
# 992.062

# %% [markdown]
# ## Use predefined common lossees

# %%
import tensorflow as tf 
import numpy as np 


n,d,h=64,1000,100
x = tf.placeholder(tf.float32, shape=(n,d))
y = tf.placeholder(tf.float32, shape=(n,d))
w1 = tf.Variable(tf.random_normal((d,h)))
w2 = tf.Variable(tf.random_normal((h,d)))

h = tf.maximum(tf.matmul(x,w1),0)
y_pred = tf.matmul(h,w2)
diff = y_pred -y
loss = tf.losses.mean_pairwise_squared_error(y_pred , y)


optimizer = tf.train.GradientDescentOptimizer(1e-5)
updates = optimizer.minimize(loss)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    valuse = {x: np.random.randn(n,d),
             y : np.random.randn(n,d),}
    losses = []
    for t in range(50):
        loss_val,_= sess.run([loss,updates] , feed_dict=valuse)
        print(loss_val)
# Out:
# 6160337.0
# 5482779.0
# 4911579.5
# 4424041.0
# 4003422.5
# 3637518.0
# 3316744.0
# 3033804.5
# 2782808.5
# 2559055.5
# 2358731.8
# 2178715.8
# 2016368.5
# 1869447.1
# 1736147.8
# 1614863.1
# 1504247.1
# 1403109.8
# 1310460.2
# 1225421.8
# 1147184.5
# 1075122.8
# 1008610.5
# 947134.5
# 890260.9
# 837569.3
# 788683.5
# 743279.75
# 701048.0
# 661729.6
# 625088.25
# 590895.25
# 558962.6
# 529103.25
# 501163.3
# 474998.62
# 450469.4
# 427454.06
# 405840.12
# 385530.88
# 366430.38
# 348450.62
# 331510.44
# 315530.25
# 300461.9
# 286241.25
# 272814.2
# 260124.9
# 248127.62
# 236775.23

# %%
N,D,H =64,100,100
x=tf.placeholder(tf.float32,shape=(N,D))
y=tf.placeholder(tf.float32,shape=(N,D))

init=tf.variance_scaling_initializer(2.0)
h=tf.layers.dense(inputs=x, units=H, activation=tf.nn.relu,kernel_initializer=init)
y_pred=tf.layers.dense(inputs=h, units=D,kernel_initializer=init)

loss=tf.losses.mean_squared_error(y_pred,y)

optimizer=tf.train.GradientDescentOptimizer(1e-5)
updates=optimizer.minimize(loss)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    values={x:np.random.randn(N,D),
            y:np.random.randn(N,D)}
    losses=[]
    for t in range(50):
        loss_val,_=sess.run([loss,updates],feed_dict=values)
        print(loss_val)
# Out:
# 3.0600598
# 3.0600421
# 3.0600255
# 3.0600085
# 3.0599914
# 3.059973
# 3.0599554
# 3.059937
# 3.05992
# 3.059901
# 3.0598834
# 3.0598657
# 3.0598474
# 3.0598297
# 3.059811
# 3.059793
# 3.0597754
# 3.059759
# 3.0597413
# 3.0597234
# 3.059706
# 3.0596871
# 3.0596697
# 3.059652
# 3.059634
# 3.0596163
# 3.0595982
# 3.0595791
# 3.0595617
# 3.059544
# 3.0595257
# 3.0595088
# 3.0594902
# 3.0594726
# 3.0594547
# 3.0594373
# 3.0594194
# 3.0594015
# 3.059383
# 3.0593657
# 3.059348
# 3.0593305
# 3.059313
# 3.0592952
# 3.0592778
# 3.0592601
# 3.0592432
# 3.0592265
# 3.0592077
# 3.0591893

# %% [markdown]
# ## use keras

# %%
import tensorflow as tf 
import numpy as np 


n,d,h=64,1000,100
x = tf.placeholder(tf.float32, shape=(n,d))
y = tf.placeholder(tf.float32, shape=(n,d))
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(h, input_shape=(d,), activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(d))
y_pred = model(x)

loss = tf.losses.mean_pairwise_squared_error(y_pred, y)


optimizer = tf.train.GradientDescentOptimizer(1e0)
updates = optimizer.minimize(loss)

with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    valuse = {x: np.random.randn(n,d),
             y : np.random.randn(n,d),}
    losses = []
    for t in range(50):
        loss_val,_= sess.run([loss,updates] , feed_dict=valuse)
        print(loss_val)
# Out:
# 148.61179
# 897.50684
# 165844830.0
# 5.005265e+24
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan
# nan

# %%
N,D,H = 64, 1000 , 100
model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(H, input_shape=(D,),activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(D))
model.compile(loss=tf.keras.losses.mean_squared_error,
             optimizer=tf.keras.optimizers.SGD(lr=1e-5))
x= np.random.randn(N, D)
y= np.random.randn(N, D)

history= model.fit(x,y, epochs=50, batch_size=N)
# Out:
# Epoch 1/50
# 64/64 [==============================] - 0s 7ms/step - loss: 1.1548
# Epoch 2/50
# 64/64 [==============================] - 0s 109us/step - loss: 1.1548
# Epoch 3/50
# 64/64 [==============================] - 0s 156us/step - loss: 1.1548
# Epoch 4/50
# 64/64 [==============================] - 0s 109us/step - loss: 1.1548
# Epoch 5/50
# 64/64 [==============================] - 0s 125us/step - loss: 1.1548
# Epoch 6/50
# 64/64 [==============================] - 0s 62us/step - loss: 1.1548
# Epoch 7/50
# 64/64 [==============================] - 0s 125us/step - loss: 1.1548
# Epoch 8/50
# 64/64 [==============================] - 0s 62us/step - loss: 1.1548
# Epoch 9/50
# 64/64 [==============================] - 0s 93us/step - loss: 1.1548
# Epoch 10/50
# 64/64 [==============================] - 0s 109us/step - loss: 1.1548
# Epoch 11/50
# 64/64 [==============================] - 0s 125us/step - loss: 1.1548
# Epoch 12/50
# 64/64 [==============================] - 0s 78us/step - loss: 1.1548
# Epoch 13/50
# 64/64 [==============================] - 0s 125us/step - loss: 1.1548
# Epoch 14/50
# 64/64 [==============================] - 0s 78us/step - loss: 1.1548
# Epoch 15/50
# 64/64 [==============================] - 0s 156us/step - loss: 1.1548
# Epoch 16/50
# 64/64 [==============================] - 0s 94us/step - loss: 1.1548
# Epoch 17/50
# 64/64 [==============================] - 0s 109us/step - loss: 1.1548
# Epoch 18/50
# 64/64 [==============================] - 0s 109us/step - loss: 1.1548
# Epoch 19/50
# 64/64 [==============================] - 0s 109us/step - loss: 1.1548
# Epoch 20/50
# 64/64 [==============================] - 0s 78us/step - loss: 1.1548
# Epoch 21/50
# 64/64 [==============================] - 0s 171us/step - loss: 1.1548
# Epoch 22/50
# 64/64 [==============================] - 0s 140us/step - loss: 1.1548
# Epoch 23/50
# 64/64 [==============================] - 0s 94us/step - loss: 1.1548
# Epoch 24/50
# 64/64 [==============================] - 0s 140us/step - loss: 1.1548
# Epoch 25/50
# 64/64 [==============================] - 0s 78us/step - loss: 1.1548
# Epoch 26/50
# 64/64 [==============================] - 0s 140us/step - loss: 1.1548
# Epoch 27/50
# 64/64 [==============================] - 0s 109us/step - loss: 1.1548
# Epoch 28/50
# 64/64 [==============================] - 0s 93us/step - loss: 1.1548
# Epoch 29/50
# 64/64 [==============================] - 0s 140us/step - loss: 1.1548
# Epoch 30/50
# 64/64 [==============================] - 0s 281us/step - loss: 1.1548
# Epoch 31/50
# 64/64 [==============================] - 0s 218us/step - loss: 1.1548
# Epoch 32/50
# 64/64 [==============================] - 0s 171us/step - loss: 1.1548
# Epoch 33/50
# 64/64 [==============================] - 0s 249us/step - loss: 1.1548
# Epoch 34/50
# 64/64 [==============================] - 0s 171us/step - loss: 1.1548
# Epoch 35/50
# 64/64 [==============================] - 0s 125us/step - loss: 1.1548
# Epoch 36/50
# 64/64 [==============================] - 0s 125us/step - loss: 1.1548
# Epoch 37/50
# 64/64 [==============================] - 0s 140us/step - loss: 1.1548
# Epoch 38/50
# 64/64 [==============================] - 0s 156us/step - loss: 1.1548
# Epoch 39/50
# 64/64 [==============================] - 0s 109us/step - loss: 1.1548
# Epoch 40/50
# 64/64 [==============================] - 0s 109us/step - loss: 1.1548
# Epoch 41/50
# 64/64 [==============================] - 0s 78us/step - loss: 1.1548
# Epoch 42/50
# 64/64 [==============================] - 0s 94us/step - loss: 1.1548
# Epoch 43/50
# 64/64 [==============================] - 0s 109us/step - loss: 1.1548
# Epoch 44/50
# 64/64 [==============================] - 0s 125us/step - loss: 1.1548
# Epoch 45/50
# 64/64 [==============================] - 0s 94us/step - loss: 1.1548
# Epoch 46/50
# 64/64 [==============================] - 0s 109us/step - loss: 1.1548
# Epoch 47/50
# 64/64 [==============================] - 0s 78us/step - loss: 1.1548
# Epoch 48/50
# 64/64 [==============================] - 0s 156us/step - loss: 1.1548
# Epoch 49/50
# 64/64 [==============================] - 0s 94us/step - loss: 1.1548
# Epoch 50/50
# 64/64 [==============================] - 0s 125us/step - loss: 1.1548
